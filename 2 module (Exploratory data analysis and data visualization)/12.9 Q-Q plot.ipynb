# %% [markdown]
# # Q-Q Plot

# %%
import numpy as np, pylab
import pylab 
import scipy.stats as stats

# N(0,1)
std_normal = np.random.normal(loc=0, scale=1, size=1000) # mean=loc, sd=scale

# 0 to 100th percentiles of std-normal
for i in range(0,101):
    print(i, np.percentile(std_normal,i))
# Out:
# 0 -2.7108717057706597
# 1 -2.2922987180435217
# 2 -2.121114564792597
# 3 -1.9880623730006453
# 4 -1.8483793542349163
# 5 -1.6987703718770197
# 6 -1.610727751543041
# 7 -1.5432428222083754
# 8 -1.452556121059119
# 9 -1.3621707195084471
# 10 -1.312196934238229
# 11 -1.2308801557572078
# 12 -1.1891618912247184
# 13 -1.1303518253590163
# 14 -1.088070384763158
# 15 -1.037726049530146
# 16 -1.0101709501168268
# 17 -0.9637938068012367
# 18 -0.9317499107035727
# 19 -0.8908546445169573
# 20 -0.8449229166899768
# 21 -0.8051180726022185
# 22 -0.7691746921603306
# 23 -0.7441108220136387
# 24 -0.7243365231457835
# 25 -0.6919405638293431
# 26 -0.6692761944320144
# 27 -0.6275649674192949
# 28 -0.5922622119560793
# 29 -0.5484664800729258
# 30 -0.5153735606898608
# 31 -0.4871061867952712
# 32 -0.45088975894060956
# 33 -0.4087067743816165
# 34 -0.3715093743989153
# 35 -0.35711586339634327
# 36 -0.33008306457374903
# 37 -0.3104829513103016
# 38 -0.28985639396784546
# 39 -0.2718332347539551
# ...

# %%
# generate 100 samples from N(20,5)
measurements = np.random.normal(loc=20, scale=5, size=100) 

#try size=1000

stats.probplot(measurements, dist="norm", plot=pylab)
pylab.show()

# %% [markdown]
# from the above plot we can clearly see that the distribution is almost linear for a data set size of 100 from N(20, 5)

# %%
# generate 1000 samples from N(20,5)
measurements = np.random.normal(loc=20, scale=5, size=1000) 

stats.probplot(measurements, dist="norm", plot=pylab)
pylab.show()

# %% [markdown]
# here from the above ploat, the distribution for 1000 data is more linear that the data of size 100 in the previous example

# %%
# generate 100 sanples from uniform distrubution
measurements = np.random.uniform(low=-1, high=1, size=100) 
#try size=1000

stats.probplot(measurements, dist="norm", plot=pylab)
pylab.show()

# %%
# generate 1000 sanples from uniform distrubution
measurements = np.random.uniform(low=-1, high=1, size=1000) 

stats.probplot(measurements, dist="norm", plot=pylab)
pylab.show()

# %% [markdown]
# from the above two plots, when we plot the Q-Q plot of data from normal distribution, then we get a distribution lik 'S' shape
# but in the case of Guassian distribution it is linear
